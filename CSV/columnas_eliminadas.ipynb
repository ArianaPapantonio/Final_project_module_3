# %%
import pandas as pd
import numpy as np


pd.set_option('display.max_columns', None)

# %%
df_numericos_limpio = pd.read_csv('numericos_limpio_1.csv', index_col=0)
df_numericos_limpio.head(1)
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
#
#    employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0               1                        1  251.965278               3
#
#    joblevel  jobsatisfaction  monthlyincome  monthlyrate  numcompaniesworked  \
# 0         5                3       16280.83     42330.17                   7
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
#
# ...

# %%
df_categoricos_limpio = pd.read_csv('categoricos_limpio.csv', index_col=0)
df_categoricos_limpio.head(10)
# Out:
#   attrition     businesstravel                department    educationfield  \
# 0        No                NaN                       NaN               NaN
# 1        No                NaN                       NaN     Life Sciences
# 2        No      travel rarely   Research & Development   Technical Degree
# 3        No      travel rarely                       NaN           Medical
# 4        No                NaN                       NaN  Technical Degree
# 5        No                NaN   Research & Development            Medical
# 6        No                NaN                       NaN     Life Sciences
# 7        No      travel rarely                       NaN               NaN
# 8        No                NaN                       NaN               NaN
# 9        No  travel frequently                       NaN               NaN
#
#   gender              jobrole maritalstatus over18 overtime standardhours  \
# ...

# %%
df_categoricos_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   attrition        1678 non-null   object
#  1   businesstravel   877 non-null    object
#  2   department       312 non-null    object
#  3   educationfield   904 non-null    object
#  4   gender           1678 non-null   object
#  5   jobrole          1678 non-null   object
#  6   maritalstatus    967 non-null    object
#  7   over18           740 non-null    object
#  8   overtime         982 non-null    object
#  9   standardhours    1327 non-null   object
#  10  roledepartament  312 non-null    object
#  11  remotework       1678 non-null   object
# dtypes: object(12)
# memory usage: 170.4+ KB

# %%
df_numericos_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   int64
#  1   dailyrate                 1678 non-null   float64
#  2   distancefromhome          1678 non-null   int64
#  3   education                 1678 non-null   int64
#  4   employeecount             1678 non-null   int64
#  5   employeenumber            1678 non-null   int64
#  6   environmentsatisfaction   1678 non-null   int64
#  7   hourlyrate                1678 non-null   float64
#  8   jobinvolvement            1678 non-null   int64
#  9   joblevel                  1678 non-null   int64
#  10  jobsatisfaction           1678 non-null   int64
#  11  monthlyincome             1678 non-null   float64
#  12  monthlyrate               1678 non-null   float64
#  13  numcompaniesworked        1678 non-null   int64
# ...

# %%
df_unido = pd.concat([df_categoricos_limpio, df_numericos_limpio], axis=1)

# %%
df_unido.head(3)
# Out:
#   attrition businesstravel                department    educationfield gender  \
# 0        No            NaN                       NaN               NaN      M
# 1        No            NaN                       NaN     Life Sciences      M
# 2        No  travel rarely   Research & Development   Technical Degree      M
#
#                jobrole maritalstatus over18 overtime standardhours  \
# 0   research director            NaN    Yes       No     Full Time
# 1             manager            NaN    NaN      NaN           NaN
# 2             manager        Married    NaN       No           NaN
#
#                         roledepartament remotework  age    dailyrate  \
# 0                                   NaN        yes   51  2015.722222
# 1                                   NaN        yes   52  2063.388889
# 2   manager  -  research & development         yes   42  1984.253968
#
#    distancefromhome  education  employeecount  employeenumber  \
# ...

# %%
df_unido.columns
# Out:
# Index(['attrition', 'businesstravel', 'department', 'educationfield', 'gender',
#        'jobrole', 'maritalstatus', 'over18', 'overtime', 'standardhours',
#        'roledepartament', 'remotework', 'age', 'dailyrate', 'distancefromhome',
#        'education', 'employeecount', 'employeenumber',
#        'environmentsatisfaction', 'hourlyrate', 'jobinvolvement', 'joblevel',
#        'jobsatisfaction', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'percentsalaryhike', 'performancerating', 'relationshipsatisfaction',
#        'stockoptionlevel', 'totalworkingyears', 'trainingtimeslastyear',
#        'worklifebalance', 'yearsatcompany', 'yearsincurrentrole',
#        'yearssincelastpromotion', 'yearswithcurrmanager',
#        'sameasmonthlyincome', 'datebirth', 'salary', 'numberchildren',
#        'is_equal'],
#       dtype='object')

# %%
## Eliminamos columnas innecesarias: 

columnas_eliminar = ['over18', 'maritalstatus', 'dailyrate', 'hourlyrate', 'sameasmonthlyincome', 'numberchildren', 'datebirth', 'roledepartament', 'standardhours','employeecount', 'yearsincurrentrole', 'totalworkingyears', 'is_equal']

# %%
df_unido = df_unido.drop(columns=columnas_eliminar)

# %%
df_unido.columns
# Out:
# Index(['attrition', 'businesstravel', 'department', 'educationfield', 'gender',
#        'jobrole', 'overtime', 'remotework', 'age', 'distancefromhome',
#        'education', 'employeenumber', 'environmentsatisfaction',
#        'jobinvolvement', 'joblevel', 'jobsatisfaction', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'stockoptionlevel',
#        'trainingtimeslastyear', 'worklifebalance', 'yearsatcompany',
#        'yearssincelastpromotion', 'yearswithcurrmanager', 'salary'],
#       dtype='object')

# %%
df_unido.head()
# Out:
#   attrition businesstravel                department    educationfield gender  \
# 0        No            NaN                       NaN               NaN      M
# 1        No            NaN                       NaN     Life Sciences      M
# 2        No  travel rarely   Research & Development   Technical Degree      M
# 3        No  travel rarely                       NaN           Medical      F
# 4        No            NaN                       NaN  Technical Degree      F
#
#                jobrole overtime remotework  age  distancefromhome  education  \
# 0   research director        No        yes   51                 6          3
# 1             manager       NaN        yes   52                 1          4
# 2             manager        No        yes   42                 4          2
# 3   research director       NaN         no   47                 2          4
# 4     sales executive        No         no   46                 3          3
#
# ...

# %%
df_unido.to_csv("unidos_limpio_1.csv", index=True)
