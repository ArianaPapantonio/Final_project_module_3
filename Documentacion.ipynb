# %% [markdown]
# # Documentación proyecto

# %% [markdown]
# ## Fase 1: Análisis Exploratorio de Datos(EDA)

# %% [markdown]
# ### 1) Realizamos una exploración del dataframe general
#
# (archivo: EDA-info-general.ipynb)
#
# - Visualizamos columnas, filas y tipos de datos.
# - Realizamos un resumen estadístico para variables numéricas y categóricas.
# - Calculamos total de frecuencias y porcentajes de nulos por columnas.
# - Verificamos cantidad de datos duplicados.
#
#
# ### 2) Dividimos el dataframe en dos y analizamos las columnas categóricas y numéricas:
#
# #### Exploración de columnas:
#
# Numéricas:
#
# -Columna 'age':
#
# - Descripción: La edad del empleado
# - Datatype: int64
# - Duplicados: N/A (puede repetirse)
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Cambios realizados: Convertir edades que estaban en letra a número.
#
#
# -Columna 'dailyrate':
#
# - Descripción: La tarifa diaria del empleado.
# - Datatype: float64 (no redondeado)
# - Duplicados: N/A (el salario diario puede repetirse por empleado)
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?:
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Cambios realizados:
# Mover el decimal una posición a la izquierda (EJ: fila 1677, el hourly rate es 69.532083 y el dailyrate es 556.256661. Si movemos el decimal y dividimos 55.6256661 por 8, da 6.9532083). Redondear a dos decimales.
#
#
# -Columna 'distancefromhome':
#
# - Descripción: La distancia desde el hogar del empleado hasta su lugar de trabajo.
# - Datatype: int64
# - Duplicados: N/A (la distancia puede repetirse por empleado)
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?:
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Cambios realizados:
# - Hay distancias negativas (202). Pasar a positivo.
#
#
# -Columna 'education':
#
# - Descripción: Nivel de educación del empleado (generalmente en una escala del 1 al 5).
# - Datatype: int64
# - Duplicados: N/A (la education puede repetirse por empleado)
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: No en esta, pero quizas si en la columna educationfield por medio del education level.
# - Columna similar: educationfield - relacionada
#
# Observaciones / Posibles cambios:
# - Ver si tiene relación con la columna categorica 'educationfield'. Ver en comprobaciones el código de contingencia:
#
#
# -Columna 'employeecount':
#
# - Descripción: Un contador que generalmente es 1 y se usa para contar empleados.
# - Datatype: int64
# - Duplicados: N/A (siempre es 1)
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
# - Unique: 1
# - Value counts: N/A
#
# Observaciones / Posibles cambios:
# - Ver si es útil o podemos eliminarlo.
#
#
# -Columna 'employeenumber':
#
# - Descripción: Un número de identificación único para el empleado.
# - Datatype: int64
# - Duplicados: 64
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
# - Unique: n/a (son muchos)
# - Value_counts: n/a (son muchos)
#
# Observaciones / Posibles cambios:
# - Eliminar duplicados (cuando juntemos los DF)
#
#
# -Columna 'environmentsatisfaction':
#
# - Descripción: Nivel de satisfacción del empleado en relación con su entorno de trabajo. Con valores que estan comprendidos entre el 1 y el 4, siendo el 4 el nivel de máxima satisfacción.
# - Datatype: int64
# - Duplicados: 0
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# - *Deberia ser del 1 al 4, pero va del 1 al 49* - Cambiar los numeros mayores a 4 por la moda.
#
#
# -Columna hourlyrate:
#
# - Descripción: La tarifa por hora del empleado.
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 1267 / En caso se ser mayoría de nulos, puede completarse con otra columna?: (ver con el resto de las columnas salariales)
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# - Completar con los datos de dailyrate / 8 y cambiar la coma una posición a la izquierda. Tambien readondear a dos decimales.
#
#
# -Columna jobinvolvement:
#
# - Descripción: Nivel de implicación del empleado en su trabajo.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Confirmar si el nivel mas alto es 4.
#
#
# -Columna joblevel:
#
# - Descripción: Nivel jerárquico del empleado en la empresa.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Confirmar si el 1 es el mayor nivel jerarquico o el 5.
#
#
# -Columna jobsatisfaction:
#
# - Descripción: Nivel de satisfacción del empleado con su trabajo.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: relationshipsatisfaction ?
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Confirmar si 1 es el menor o mayor nivel de satisfaccion.
#
#
# -Columna monthlyincome:
#
# - Descripción: Ingresos mensuales del empleado.
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 489 / En caso se ser mayoría de nulos, puede completarse con otra columna?: ver si hay relacion con salary
# - Columna similar: sameasmonthlyincome
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Completar nulos con el salary / 12
#
#
# -Columna monthlyrate:
#
# - Descripción: Tasa mensual del empleado.
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A - ver con hourlyrate
# - Columna similar: sameasmonthlyincome
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Mover el decimal una posición a la izquierda
#
#
# -Columna numcompaniesworked:
#
# - Descripción: Número de compañías en las que el empleado ha trabajado.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna percentsalaryhike:
#
# Info:
# - Descripción: El porcentaje de aumento salarial del empleado.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna performancerating:
#
# - Descripción: Calificación de rendimiento del empleado
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 200 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Gestionar nulos:  12.0 % nulos -
#
#
# -Columna relationshipsatisfaction:
#
# - Descripción:  Nivel de satisfacción en las relaciones interpersonales del empleado.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: jobsatisfaction?
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna stockoptionlevel:
#
# - Descripción:  Nivel de opciones de compra de acciones del empleado
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna totalworkingyears:
#
# - Descripción:  Total de años de experiencia laboral del empleado.
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 549 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: yearsatcompany??
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Gestionar nulos: 33.0 %
#
#
# -Columna trainingtimeslastyear:
#
# - Descripción:  Número de veces que el empleado recibió capacitación el año pasado.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna worklifebalance:
#
# - Descripción:  Equilibrio entre trabajo y vida personal del empleado.
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 114 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# Gestionar nulos: 7.0 %
#
#
# -Columna yearsatcompany:
#
# - Descripción:  Años que el empleado ha trabajado en la empresa actual.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: totalworkingyears ?
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna yearsincurrentrole:
#
# - Descripción:  Años que el empleado ha estado en su puesto actual
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 1643 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# tiene 98% nulos - gestionar nulos o eliminar
#
#
# -Columna yearssincelastpromotion:
#
# - Descripción:  Años desde la última promoción del empleado.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna yearswithcurrmanager:
#
# - Descripción:  Años que el empleado ha estado bajo la supervisión del actual gerente.
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# N/A
#
#
# -Columna sameasmonthlyincome:
#
# - Descripción:  Ingresos mensuales del empleado
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 489 / En caso se ser mayoría de nulos, puede completarse con otra columna?: tiene los mismos  nulos que monthlyincome
# - Columna similar: monthlyincome
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# **Eliminar : es igual a la de monthlyincome
#
#
# -Columna datebirth:
#
# - Descripción: Año de nacimiento del empleado (teniendo en cuenta que los datos fueron recogidos en el 2023)
# - Datatype: int64
# - Duplicados: N/A
# - Nulos: 0 / En caso se ser mayoría de nulos, puede completarse con otra columna?: tiene los mismos  nulos que monthlyincome
# - Columna similar:
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# ** Eliminar: ya tenemos columna de edad.
#
#
# -Columna salary:
#
# - Descripción:  salario de los empleados
# - Datatype: float64
# - Duplicados: N/A
# - Nulos: 285 / En caso se ser mayoría de nulos, puede completarse con otra columna?: ver monthlyincome o monthlyrate a ver si hay relacion
# - Columna similar: monthlyincome / monthlyrate * 12 ?
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# ver relacion con las otras dos de income / rate
#
#
# -Columna numberchildren:
#
# - Descripción:  numero de hijos
# - Datatype: float64 - ver si deberia ser int
# - Duplicados: N/A
# - Nulos: 1677 / En caso se ser mayoría de nulos, puede completarse con otra columna?: N/A
# - Columna similar: N/A
# - Mantener como columna numérica? Si
#
# Observaciones / Posibles cambios:
# ** Eliminar: 100 % nulos.
#
#
# Categóricas:
#
# - En la columna de "genre" cambiar los valores 0 y 1 a M y F
# - En la columna de "Distancefromhome" quitar los valores negativos
# - Pasar todo a minuscula

# %% [markdown]
# ## Fase 2: Transformación de los datos

# %% [markdown]
# 1) Modificaciones en columnas categóricas:
#
# - Modificamos la columna genre para cambiar valores 0 y 1 a M y F.
# - Modificamos la columna remotework para reemplazar 0 por 'no', 1 por 'yes' y 'false' por 'no.
# - Reemplazamos los guiones bajos en la columna de businesstravel por espacios.
# - Cambiamos a minuscula los datos de la columnas jobrole y roledepartment.
# - Corregimos errores ortográficos en columna maritalstatus ('marreid por married y divorcerd por Divorced)
# - En columna over18 reemplazamos y por yes.
#
# Archivo: categoricos.ipynb
#
# 2) Modificaciones en columnas numéricas:
#
# - Cambiamos a positivo los valores de la columna distancefromhome.
# - Convertimos a un digito todo lo que era mayor a 4 en columna enviromentsatisfaction.
# - Calculamos si el monthlyincome era el salario dividido 12. Una vez confirmado reemplazamos los nulos con los valores de estas columnas.
# - Calculamos el dailyrate / 8 para confirmar que fuera el hourlyrate. Una vez comprobado, completamos nulos con este calculo.
#
# Archivo: numericos.ipynb
#
# 3) Unimos los dataframes y realizamos la gestion de los nulos y duplicados:
#
# Columnas:
#
# businesstravel: rellenamos con non travel
# department: rellenamos con Unknown
# educationfield: rellenamos con Unknown
# overtime: rellenamos con la moda
# performancerating: rellenamos con la mediana
# worklifebalance: rellenamos con la mediana
#
# Eliminamos los duplicados (64) del dataframe ya que habia employeenumber IDs repetidos.
#
# Archivo: data_junta.ipynb
#
# 4) Eliminación de columnas:
#
# Eliminamos las columnas irrelevantes para el estudio: 'over18', 'maritalstatus', 'dailyrate', 'hourlyrate', 'sameasmonthlyincome', 'numberchildren', 'datebirth', 'roledepartament', 'standardhours','employeecount', 'yearsincurrentrole', 'totalworkingyears', 'is_equal'
#
# Archivo: columnas_eliminadas.ipynb.

# %% [markdown]
# ## Fase 3: Creación de la BBDD.

# %% [markdown]
# Empezamos importando las librerías necesarias, pasamos los csv a dataframes, e insertamos los datos para su tabla correspondiente. Te explico el esquema y las tablas:
#
# - Este esquema contiene varias tablas relacionadas entre sí que almacenan información sobre empleados y su nivel de satisfacción, salario y trabajo en una organización. Aquí te proporciono una explicación detallada para cada tabla y las relaciones entre ellas.
#
# 1) **Tabla: `info_personal`**:
#
# Esta tabla almacena información personal de cada empleado.
# Las columnas son:
#
# - `employeenumber`
#
# - `age`
#
# - `gender`
#
# - `education`
#
# - `educationfield`
#
# - **Clave primaria:** `employeenumber` es la clave primaria de la tabla, lo que asegura que cada empleado tenga un identificador único.
#
# 2) **Tabla: `satisfaccion`**:
#
# Esta tabla almacena los niveles de satisfacción del empleado en diferentes áreas.
# Las columnas son:
#
# - `employeenumber`
#
# - `environmentsatisfaction`
#
# - `relationshipsatisfaction`
#
# - `jobsatisfaction`
#
# - `jobinvolvement`
#
# - `performancerating`
#
# - `worklifebalance`
# - **Clave primaria y clave foránea:**
#      - La clave primaria es `employeenumber`.
#      - `employeenumber` es también una clave foránea (`FOREIGN KEY`) que se refiere al campo `employeenumber` en la tabla `info_personal`.
#
#
# 3) **Tabla: `info_salario`**:
#
# Esta tabla almacena la información relacionada con el salario de los empleados.
# Las columnas son:
#
# - `employeenumber`
#
# - `monthlyincome`
#
# - `monthlyrate`
#
# - `percentsalaryhike`
#
# - `salary`
#
# - **Clave primaria y clave foránea:**
#      - La clave primaria es `employeenumber`.
#      - `employeenumber` es también una clave foránea que se refiere a `info_personal`.
#
# 4) **Tabla: `info_trabajo`**:
#
# Esta tabla almacena información relacionada con las características laborales de los empleados.
# Las columnas son:
#
# - `employeenumber`
#
# - `attrition`
#
# - `businesstravel`
#
# - `jobrole`
#
# - `department`
#
# - `joblevel`
#
# - `overtime`
#
# - `remotework`
#
# - `distancefromhome`
#
# -`numcompaniesworked`
#
# - `trainingtimeslastyear`
#
# - `yearsatcompany`
#
# - `yearssincelastpromotion`
#
# - `yearswithcurrmanager`
#
# - `stockoptionlevel`
#
#  - **Clave primaria y clave foránea:**
#      - La clave primaria es `employeenumber`.
#      - `employeenumber` es también una clave foránea que se refiere a `info_personal`.

# %% [markdown]
# ## Fase 4: Problema de A/B Testing

# %% [markdown]
# ## Fase 5: Creación de ETL

# %% [markdown]
# En esta fase hemos creado una carpeta llamada "src", y hemos creado unos soportes que son:
#
# - Soporte_bbdd
#
# - Soporte_funciones
#
# - Soporte_queries
#
# 1) Soporte BBDD:
#
# Hemos creado dos funciones las cuales son:
#
# - Creación de la BBDD
#
# - Insertar los datos a la base de datos
#
# 2) Funciones:
#
# Hemos creado cinco funciones que son:
#
# - Exploracion
#
# - Convertir a numero
#
# - Cambiar a comas
#
# - Normalidad
#
# - Test Mann-Whitney
#
# 3) Queries:
#
# Nosotras optamos hacerlo directamente desde SQL, pero aqui tenemos el soporte de la creacion de tablas de la base de datos.
#
# - query_creacion_tabla_info_personal
#
# - query_creacion_tabla_satisfaccion
#
# - query_creacion_tabla_info_salario
#
# - query_creacion_tabla_info_trabajo

# %% [markdown]
# ## Fase 6: Reporte de los resultados

# %% [markdown]
# Tenemos que generar un PowerPoint que permitirá una comprensión más profunda de la situación actual y servirá como base para la toma de decisiones informadas, también tenemos que incluir visualizaciones que ayudarán a resaltar tendencias, áreas de mejora y fortalezas dentro de la empresa.
