# %%
import pandas as pd
import numpy as np


pd.set_option('display.max_columns', None)

# %%
df_numericos = pd.read_csv('numericos.csv', index_col=0)

# %%
df_categoricos=pd.read_csv("categoricos.csv", index_col=0)

# %%
# Mostrar las ultimas 5 filas
df_categoricos.tail()
# Out:
#      attrition businesstravel department educationfield  gender  \
# 1673        No            NaN        NaN        Medical       1
# 1674        No            NaN        NaN            NaN       1
# 1675        No  travel_rarely        NaN            NaN       0
# 1676        No  travel_rarely        NaN  Life Sciences       1
# 1677        No            NaN        NaN  Life Sciences       1
#
#                        jobrole maritalstatus over18 overtime standardhours  \
# 1673       rESEaRcH SciEnTiST         Single    NaN      NaN           NaN
# 1674                  mANager        Married      Y       No     Full Time
# 1675       reSearch sCienTiSt            NaN    NaN       No     Part Time
# 1676   maNufACTURING DIREctOr       Divorced    NaN      Yes     Part Time
# 1677       resEArch scIENTisT         Single      Y      Yes     Part Time
#
#      roledepartament remotework
# 1673             NaN        Yes
# 1674             NaN      False
# 1675             NaN      False
# 1676             NaN        Yes
# 1677             NaN          0

# %%
# Mostrar las ultimas 5 filas
df_numericos.tail()
# Out:
#       age    dailyrate  distancefromhome  education  employeecount  \
# 1673   43   488.944444               -26          3              1
# 1674   47  1973.984127                26          4              1
# 1675   29   290.035510                15          3              1
# 1676   47  1032.487286                 4          3              1
# 1677   32   556.256661                 2          2              1
#
#       employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# 1673             824                        2         NaN               4
# 1674            1087                        4         NaN               3
# 1675             528                        3         NaN               3
# 1676              76                        3         NaN               2
# 1677             401                        4   69.532083               3
#
#       joblevel  jobsatisfaction  monthlyincome  monthlyrate  \
# 1673         1                3        3949.17     10267.83
# 1674         5                3       15943.72     41453.67
# 1675         1                4            NaN      6090.75
# 1676         3                2        8339.32     21682.23
# 1677         2                3            NaN     11681.39
#
#       numcompaniesworked  percentsalaryhike  performancerating  \
# 1673                   4                 12                3.0
# 1674                   3                 11                3.0
# 1675                   1                 19                3.0
# 1676                   8                 12                NaN
# 1677                   4                 14                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 1673                         4                 0                NaN
# 1674                         3                 1               27.0
# 1675                         1                 0                6.0
# 1676                         3                 1                NaN
# 1677                         4                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 1673                      2              3.0               3
# 1674                      2              3.0               5
# 1675                      1              3.0               6
# 1676                      4              3.0              22
# 1677                      2              3.0               8
#
#       yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 1673                 NaN                        1                     2
# 1674                 NaN                        1                     0
# 1675                 NaN                        1                     5
# 1676                 NaN                       14                    10
# 1677                 NaN                        0                     7
#
#       sameasmonthlyincome  datebirth     salary  numberchildren
# 1673              3949.17       1980        NaN             NaN
# 1674             15943.72       1976  191324.62             NaN
# 1675                  NaN       1994   28111.13             NaN
# 1676              8339.32       1976  100071.84             NaN
# 1677                  NaN       1991   53914.11             NaN

# %%
## Verificamos relacion entre columna 'salary' y 'monthlyincome'

df_numericos['is_equal'] = df_numericos.apply(lambda row: round(row['salary'] / 12, 2) == round(row['monthlyincome'],2)
                          if pd.notnull(row['salary']) and pd.notnull(row['monthlyincome'])
                          else None, axis=1)

# %%
df_numericos.tail()
# Out:
#       age    dailyrate  distancefromhome  education  employeecount  \
# 1673   43   488.944444                26          3              1
# 1674   47  1973.984127                26          4              1
# 1675   29   290.035510                15          3              1
# 1676   47  1032.487286                 4          3              1
# 1677   32   556.256661                 2          2              1
#
#       employeenumber environmentsatisfaction  hourlyrate  jobinvolvement  \
# 1673             824                       1   61.118056               4
# 1674            1087                       1  246.748016               3
# 1675             528                       1   36.254439               3
# 1676              76                       1  129.060911               2
# 1677             401                       1   69.532083               3
#
#       joblevel  jobsatisfaction  monthlyincome  monthlyrate  \
# 1673         1                3        3949.17     10267.83
# 1674         5                3       15943.72     41453.67
# 1675         1                4            NaN      6090.75
# 1676         3                2        8339.32     21682.23
# 1677         2                3            NaN     11681.39
#
#       numcompaniesworked  percentsalaryhike  performancerating  \
# 1673                   4                 12                3.0
# 1674                   3                 11                3.0
# 1675                   1                 19                3.0
# 1676                   8                 12                NaN
# 1677                   4                 14                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 1673                         4                 0                NaN
# 1674                         3                 1               27.0
# 1675                         1                 0                6.0
# 1676                         3                 1                NaN
# 1677                         4                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 1673                      2              3.0               3
# 1674                      2              3.0               5
# 1675                      1              3.0               6
# 1676                      4              3.0              22
# 1677                      2              3.0               8
#
#       yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 1673                 NaN                        1                     2
# 1674                 NaN                        1                     0
# 1675                 NaN                        1                     5
# 1676                 NaN                       14                    10
# 1677                 NaN                        0                     7
#
#       sameasmonthlyincome  datebirth     salary  numberchildren is_equal
# 1673              3949.17       1980        NaN             NaN     None
# 1674             15943.72       1976  191324.62             NaN     True
# 1675                  NaN       1994   28111.13             NaN     None
# 1676              8339.32       1976  100071.84             NaN     True
# 1677                  NaN       1991   53914.11             NaN     None

# %%
# El número de valores nulos
df_numericos['is_equal'].isnull().sum()
# Out:
# 774

# %%
# Número de valores nulos 
df_numericos['salary'].isnull().sum()
# Out:
# 285

# %%
## Distance from home: cambiamos valores negativos a positivo: 

df_numericos['distancefromhome'] = df_numericos['distancefromhome'].abs()

# %%
df_numericos['distancefromhome'].value_counts()
# Out:
# distancefromhome
# 2     228
# 1     209
# 10     92
# 9      89
# 8      85
# 7      82
# 3      79
# 5      65
# 4      64
# 6      63
# 24     37
# 16     37
# 12     33
# 13     33
# 11     33
# 18     32
# 15     31
# 25     31
# 26     30
# 29     30
# 23     30
# 14     28
# 19     23
# 20     23
# 17     22
# 21     22
# 22     21
# 28     20
# 27     18
# 47      8
# 35      8
# 38      7
# 31      6
# 36      6
# 42      6
# 45      6
# 48      5
# 37      5
# 46      5
# 32      4
# 41      4
# 30      4
# 33      3
# 44      3
# 34      2
# 49      2
# 43      2
# 39      1
# 40      1
# Name: count, dtype: int64

# %%
df_numericos['employeenumber'].isnull().sum()
# Out:
# 0

# %%
df_numericos['environmentsatisfaction'].value_counts()
# Out:
# environmentsatisfaction
# 4     483
# 3     471
# 2     316
# 1     306
# 35      7
# 12      7
# 14      6
# 13      6
# 24      5
# 47      5
# 36      4
# 48      4
# 41      4
# 46      4
# 42      4
# 45      3
# 11      3
# 22      3
# 17      3
# 18      3
# 20      3
# 25      3
# 27      3
# 37      2
# 29      2
# 19      2
# 38      2
# 31      2
# 15      2
# 16      2
# 26      1
# 39      1
# 10      1
# 49      1
# 21      1
# 28      1
# 33      1
# 43      1
# Name: count, dtype: int64

# %%
df_numericos['performancerating'].value_counts()
# Out:
# performancerating
# 3.0    1257
# 4.0     221
# Name: count, dtype: int64

# %%
df_numericos.columns
# Out:
# Index(['age', 'dailyrate', 'distancefromhome', 'education', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobsatisfaction', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'numberchildren', 'is_equal'],
#       dtype='object')

# %%
df_numericos['hourlyrate'].isnull().sum()
# Out:
# 1267

# %%
df_numericos['dailyrate'].isnull().sum()
# Out:
# 0

# %%
## Tenemos que completar la columna de hourlyrate con los datos de daily rate (dailyrate / 8): 

df_numericos['hourlyrate'] = df_numericos['dailyrate'] / 8

# %%
#Comprobamos el cambio: 

df_numericos.head()
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
# 1   52  2063.388889                 1          4              1
# 2   42  1984.253968                 4          2              1
# 3   47  1771.404762                 2          4              1
# 4   46  1582.771346                 3          3              1
#
#    employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0               1                        1  251.965278               3
# 1               2                        3  257.923611               2
# 2               3                        3  248.031746               3
# 3               4                        1  221.425595               3
# 4               5                        1  197.846418               4
#
#    joblevel  jobsatisfaction  monthlyincome  monthlyrate  numcompaniesworked  \
# 0         5                3       16280.83     42330.17                   7
# 1         5                3            NaN     43331.17                   0
# 2         5                4            NaN     41669.33                   1
# 3         4                3       14307.50     37199.50                   3
# 4         4                1       12783.92     33238.20                   2
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
# 1                 14                3.0                         1
# 2                 11                3.0                         4
# 3                 19                3.0                         2
# 4                 12                3.0                         4
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary  numberchildren
# 0       1972  195370.0             NaN
# 1       1971  199990.0             NaN
# 2       1981  192320.0             NaN
# 3       1976  171690.0             NaN
# 4       1977       NaN             NaN

# %%
df_numericos['environmentsatisfaction'].unique()
# Out:
# array([ 1,  3,  4,  2, 42, 37, 35, 25, 27, 31, 39, 21, 15, 14, 33, 19, 12,
#        13, 28, 47, 36, 29, 24, 46, 16, 22, 41, 49, 11, 48, 18, 10, 45, 38,
#        17, 20, 26, 43])

# %%
## Cambiamos los valores de 'enviromentsatisfaction' (los que tienen mas de un digito deben tener uno solo)

labels = [1, 2, 3, 4] 

df_numericos['environmentsatisfaction'] = pd.cut(df_numericos['environmentsatisfaction'], bins=4, labels=labels, right=True) # Mostrar el DataFrame modificadoprint(df)

# %%
df_numericos['environmentsatisfaction'].value_counts()
# Out:
# environmentsatisfaction
# 1    1593
# 2      33
# 4      29
# 3      23
# Name: count, dtype: int64

# %%
df_numericos['is_equal'] = df_numericos.apply(lambda row: round(row['salary'] / 12, 2) == round(row['monthlyincome'],2)
                          if pd.notnull(row['salary']) and pd.notnull(row['monthlyincome'])
                          else None, axis=1)

# %%
df_numericos
# Out:
#       age    dailyrate  distancefromhome  education  employeecount  \
# 0      51  2015.722222                 6          3              1
# 1      52  2063.388889                 1          4              1
# 2      42  1984.253968                 4          2              1
# 3      47  1771.404762                 2          4              1
# 4      46  1582.771346                 3          3              1
# ...   ...          ...               ...        ...            ...
# 1673   43   488.944444                26          3              1
# 1674   47  1973.984127                26          4              1
# 1675   29   290.035510                15          3              1
# 1676   47  1032.487286                 4          3              1
# 1677   32   556.256661                 2          2              1
#
#       employeenumber environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0                  1                       1  251.965278               3
# 1                  2                       1  257.923611               2
# 2                  3                       1  248.031746               3
# 3                  4                       1  221.425595               3
# 4                  5                       1  197.846418               4
# ...              ...                     ...         ...             ...
# 1673             824                       1   61.118056               4
# 1674            1087                       1  246.748016               3
# 1675             528                       1   36.254439               3
# 1676              76                       1  129.060911               2
# 1677             401                       1   69.532083               3
#
#       joblevel  jobsatisfaction  monthlyincome  monthlyrate  \
# 0            5                3       16280.83     42330.17
# 1            5                3            NaN     43331.17
# 2            5                4            NaN     41669.33
# 3            4                3       14307.50     37199.50
# 4            4                1       12783.92     33238.20
# ...        ...              ...            ...          ...
# 1673         1                3        3949.17     10267.83
# 1674         5                3       15943.72     41453.67
# 1675         1                4            NaN      6090.75
# 1676         3                2        8339.32     21682.23
# 1677         2                3            NaN     11681.39
#
#       numcompaniesworked  percentsalaryhike  performancerating  \
# 0                      7                 13                3.0
# 1                      0                 14                3.0
# 2                      1                 11                3.0
# 3                      3                 19                3.0
# 4                      2                 12                3.0
# ...                  ...                ...                ...
# 1673                   4                 12                3.0
# 1674                   3                 11                3.0
# 1675                   1                 19                3.0
# 1676                   8                 12                NaN
# 1677                   4                 14                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 0                            3                 0                NaN
# 1                            1                 1               34.0
# 2                            4                 0               22.0
# 3                            2                 2                NaN
# 4                            4                 1                NaN
# ...                        ...               ...                ...
# 1673                         4                 0                NaN
# 1674                         3                 1               27.0
# 1675                         1                 0                6.0
# 1676                         3                 1                NaN
# 1677                         4                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 0                         5              3.0              20
# 1                         5              3.0              33
# 2                         3              NaN              22
# 3                         2              NaN              20
# 4                         5              3.0              19
# ...                     ...              ...             ...
# 1673                      2              3.0               3
# 1674                      2              3.0               5
# 1675                      1              3.0               6
# 1676                      4              3.0              22
# 1677                      2              3.0               8
#
#       yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                    NaN                       15                    15
# 1                    NaN                       11                     9
# 2                    NaN                       11                    15
# 3                    NaN                        5                     6
# 4                    NaN                        2                     8
# ...                  ...                      ...                   ...
# 1673                 NaN                        1                     2
# 1674                 NaN                        1                     0
# 1675                 NaN                        1                     5
# 1676                 NaN                       14                    10
# 1677                 NaN                        0                     7
#
#       sameasmonthlyincome  datebirth     salary  numberchildren is_equal
# 0                16280.83       1972  195370.00             NaN     True
# 1                     NaN       1971  199990.00             NaN     None
# 2                     NaN       1981  192320.00             NaN     None
# 3                14307.50       1976  171690.00             NaN     True
# 4                12783.92       1977        NaN             NaN     None
# ...                   ...        ...        ...             ...      ...
# 1673              3949.17       1980        NaN             NaN     None
# 1674             15943.72       1976  191324.62             NaN     True
# 1675                  NaN       1994   28111.13             NaN     None
# 1676              8339.32       1976  100071.84             NaN     True
# 1677                  NaN       1991   53914.11             NaN     None
#
# [1678 rows x 30 columns]

# %%
df_numericos.head()
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
# 1   52  2063.388889                 1          4              1
# 2   42  1984.253968                 4          2              1
# 3   47  1771.404762                 2          4              1
# 4   46  1582.771346                 3          3              1
#
#    employeenumber environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0               1                       1  251.965278               3
# 1               2                       1  257.923611               2
# 2               3                       1  248.031746               3
# 3               4                       1  221.425595               3
# 4               5                       1  197.846418               4
#
#    joblevel  jobsatisfaction  monthlyincome  monthlyrate  numcompaniesworked  \
# 0         5                3       16280.83     42330.17                   7
# 1         5                3            NaN     43331.17                   0
# 2         5                4            NaN     41669.33                   1
# 3         4                3       14307.50     37199.50                   3
# 4         4                1       12783.92     33238.20                   2
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
# 1                 14                3.0                         1
# 2                 11                3.0                         4
# 3                 19                3.0                         2
# 4                 12                3.0                         4
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary  numberchildren is_equal
# 0       1972  195370.0             NaN     True
# 1       1971  199990.0             NaN     None
# 2       1981  192320.0             NaN     None
# 3       1976  171690.0             NaN     True
# 4       1977       NaN             NaN     None

# %%
## Tenemos que completar los 'NaN' de monthlyincome con la división de salary / 12 
# Solo actualizar las filas de 'monthlyincome' donde sea NaN
df_numericos['monthlyincome'] = df_numericos.apply(
    lambda row: row['salary'] / 12 if pd.notnull(row['salary']) and pd.isnull(row['monthlyincome']) else row['monthlyincome'],
    axis=1
)

# %%
## Tenemos que completar los 'NaN' de salary con la multiplicacion de monthlyincome * 12 
# Solo actualizar las filas de 'salary' donde sea NaN
df_numericos['salary'] = df_numericos.apply(
    lambda row: row['monthlyincome'] * 12 if pd.notnull(row['monthlyincome']) and pd.isnull(row['salary']) else row['salary'],
    axis=1
)

# %%
df_numericos['monthlyincome'] = round(df_numericos['monthlyincome'],2) ##redondeamos monthly income a dos decimales.

# %%
df_numericos.head()
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
# 1   52  2063.388889                 1          4              1
# 2   42  1984.253968                 4          2              1
# 3   47  1771.404762                 2          4              1
# 4   46  1582.771346                 3          3              1
#
#    employeenumber environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0               1                       1  251.965278               3
# 1               2                       1  257.923611               2
# 2               3                       1  248.031746               3
# 3               4                       1  221.425595               3
# 4               5                       1  197.846418               4
#
#    joblevel  jobsatisfaction  monthlyincome  monthlyrate  numcompaniesworked  \
# 0         5                3       16280.83     42330.17                   7
# 1         5                3       16665.83     43331.17                   0
# 2         5                4       16026.67     41669.33                   1
# 3         4                3       14307.50     37199.50                   3
# 4         4                1       12783.92     33238.20                   2
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
# 1                 14                3.0                         1
# 2                 11                3.0                         4
# 3                 19                3.0                         2
# 4                 12                3.0                         4
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth     salary  numberchildren is_equal
# 0       1972  195370.00             NaN     True
# 1       1971  199990.00             NaN     None
# 2       1981  192320.00             NaN     None
# 3       1976  171690.00             NaN     True
# 4       1977  153407.04             NaN     None

# %%
df_numericos.tail()
# Out:
#       age  dailyrate  distancefromhome  education  employeecount  \
# 1673   43      48.89                26          3              1
# 1674   47     197.40                26          4              1
# 1675   29      29.00                15          3              1
# 1676   47     103.25                 4          3              1
# 1677   32      55.63                 2          2              1
#
#       employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# 1673             824                      2.0        6.11               4
# 1674            1087                      4.0       24.67               3
# 1675             528                      3.0        3.63               3
# 1676              76                      3.0       12.91               2
# 1677             401                      4.0        6.95               3
#
#       joblevel  jobsatisfaction  monthlyincome  monthlyrate  \
# 1673         1                3        3949.17      1026.78
# 1674         5                3       15943.72      4145.37
# 1675         1                4        2342.59       609.08
# 1676         3                2        8339.32      2168.22
# 1677         2                3        4492.84      1168.14
#
#       numcompaniesworked  percentsalaryhike  performancerating  \
# 1673                   4                 12                3.0
# 1674                   3                 11                3.0
# 1675                   1                 19                3.0
# 1676                   8                 12                NaN
# 1677                   4                 14                3.0
#
#       relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# 1673                         4                 0                NaN
# 1674                         3                 1               27.0
# 1675                         1                 0                6.0
# 1676                         3                 1                NaN
# 1677                         4                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 1673                      2              3.0               3
# 1674                      2              3.0               5
# 1675                      1              3.0               6
# 1676                      4              3.0              22
# 1677                      2              3.0               8
#
#       yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 1673                 NaN                        1                     2
# 1674                 NaN                        1                     0
# 1675                 NaN                        1                     5
# 1676                 NaN                       14                    10
# 1677                 NaN                        0                     7
#
#       sameasmonthlyincome  datebirth     salary  numberchildren is_equal
# 1673              3949.17       1980   47390.04             NaN     None
# 1674             15943.72       1976  191324.62             NaN     True
# 1675                  NaN       1994   28111.13             NaN     None
# 1676              8339.32       1976  100071.84             NaN     True
# 1677                  NaN       1991   53914.11             NaN     None

# %%
## pasamos a CSV: 

df_numericos.to_csv("numericos_limpio_1.csv", index=True)
