# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
# Crear un dataframe
df_numericos = pd.read_csv('CSV/numericos.csv', index_col=0)

# %%
df_numericos.head(10)
# Out:
#    age    dailyrate  distancefromhome  education  employeecount  \
# 0   51  2015.722222                 6          3              1
# 1   52  2063.388889                 1          4              1
# 2   42  1984.253968                 4          2              1
# 3   47  1771.404762                 2          4              1
# 4   46  1582.771346                 3          3              1
# 5   48  1771.920635                22          3              1
# 6   59  1032.487286                25          3              1
# 7   42   556.256661                 1          1              1
# 8   41  1712.182540                 2          5              1
# 9   41  1973.984127                 9          3              1
#
#    employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# 0               1                        1         NaN               3
# 1               2                        3         NaN               2
# ...

# %%
df_numericos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   int64
#  1   dailyrate                 1678 non-null   float64
#  2   distancefromhome          1678 non-null   int64
#  3   education                 1678 non-null   int64
#  4   employeecount             1678 non-null   int64
#  5   employeenumber            1678 non-null   int64
#  6   environmentsatisfaction   1678 non-null   int64
#  7   hourlyrate                411 non-null    float64
#  8   jobinvolvement            1678 non-null   int64
#  9   joblevel                  1678 non-null   int64
#  10  jobsatisfaction           1678 non-null   int64
#  11  monthlyincome             1189 non-null   float64
#  12  monthlyrate               1678 non-null   float64
#  13  numcompaniesworked        1678 non-null   int64
# ...

# %%
df_numericos.columns
# Out:
# Index(['age', 'dailyrate', 'distancefromhome', 'education', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobsatisfaction', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'numberchildren'],
#       dtype='object')

# %% [markdown]
# ## Comprobaciones

# %%
df_numericos.columns
# Out:
# Index(['age', 'dailyrate', 'distancefromhome', 'education', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobsatisfaction', 'monthlyincome',
#        'monthlyrate', 'numcompaniesworked', 'percentsalaryhike',
#        'performancerating', 'relationshipsatisfaction', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'numberchildren'],
#       dtype='object')

# %%
# Contar cuántos valores negativos hay una columna
negativos1 = (df_numericos["numberchildren"] < 0).sum()
print(f"Número de valores negativos en 'numberchildren': {negativos1}")
# Out:
# Número de valores negativos en 'numberchildren': 0

# %%
df_numericos['numberchildren'].dtype
# Out:
# dtype('float64')

# %%
# Verificar duplicados
df_numericos['numberchildren'].duplicated().sum()
# Out:
# 1677

# %%
#Ver nulos
df_numericos['numberchildren'].isnull().sum()
# Out:
# 1678

# %%
df_numericos["numberchildren"].unique()
# Out:
# array([nan])

# %%
df_numericos['numberchildren'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)
