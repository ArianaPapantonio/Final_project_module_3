# %%
# Importaciones de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Para ver en el dataframe todas las columnas
pd.set_option('display.max_columns', None)

# %%
# Crear un dataframe, sin la primera columna
df = pd.read_csv('hr_raw_data_final.csv', index_col=0)

# %%
# Visualizar las primeras filas para entender la estructura
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# ...

# %%
# Muestra las ultimas 5 filas
df.tail()
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 1673  43        No            NaN   488.944444        NaN               -26
# 1674  47        No            NaN  1973.984127        NaN                26
# 1675  29        No  travel_rarely   290.035510        NaN                15
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# 1677  32        No            NaN   556.256661        NaN                 2
#
#       education educationfield  employeecount  employeenumber  \
# 1673          3        Medical              1             824
# 1674          4            NaN              1            1087
# 1675          3            NaN              1             528
# 1676          3  Life Sciences              1              76
# 1677          2  Life Sciences              1             401
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# ...

# %%
# Información general sobre las columnas 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %%
# Muestra cuantas filas y columnas componen el DataFrame
df.shape
print(f'El DataFrame tiene {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# El DataFrame tiene 1678 filas y 41 columnas

# %%
# Muestra los valores totales del DataFrame
df.size
print(f'El DataFrame tiene {df.size} valores')
# Out:
# El DataFrame tiene 68798 valores

# %%
# Muestra el nombre de las 41 columnas
df.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
# Resumen estadístico para variables NUMÉRICAS
df.describe().T
# Out:
#                            count         mean         std          min  \
# dailyrate                 1678.0   668.079714  470.787298   104.103175
# distancefromhome          1678.0     4.504172   14.652066   -49.000000
# education                 1678.0     2.932658    1.024270     1.000000
# employeecount             1678.0     1.000000    0.000000     1.000000
# employeenumber            1678.0   809.859952  467.084867     1.000000
# environmentsatisfaction   1678.0     4.264005    6.912695     1.000000
# gender                    1678.0     0.398689    0.489774     0.000000
# hourlyrate                 411.0    83.140768   57.272101    13.012897
# jobinvolvement            1678.0     2.740763    0.710359     1.000000
# joblevel                  1678.0     2.064362    1.099425     1.000000
# jobsatisfaction           1678.0     2.743147    1.105172     1.000000
# numcompaniesworked        1678.0     2.670441    2.501133     0.000000
# ...

# %%
# Ver un resumen para variables CATEGÓRICAS
df.describe(include=['object']).T
# Out:
#                     count unique  \
# age                  1678     54
# attrition            1678      2
# businesstravel        877      3
# department            312      3
# educationfield        904      6
# jobrole              1678   1579
# maritalstatus        1003      5
# monthlyincome        1189    493
# monthlyrate          1678    673
# over18                740      1
# overtime              982      2
# performancerating    1478      2
# standardhours        1327      2
# totalworkingyears    1129     40
# worklifebalance      1564      4
# yearsincurrentrole     35     10
# sameasmonthlyincome  1189    493
# salary               1393    583
# roledepartament       312    301
# remotework           1678      5
#
#                                                                  top  freq
# age                                                               35    88
# attrition                                                         No  1406
# ...

# %%
# Contar frecuencias de variables categóricas
for column in df.select_dtypes(include='object').columns:
    print(f"\nFrecuencias en la columna '{column}':")
    print(f"Los valores únicos son: {df[column].unique()}\n")
    print(f"Las frecuncias de los valores unicos de las categorías son: {df[column].value_counts()}")
# Out:
# Frecuencias en la columna 'age':
# Los valores únicos son: ['51' '52' '42' '47' '46' '48' '59' '41' '56' '38' '55' '40' '58' '35'
#  '45' '33' '36' '34' 'forty-seven' '53' '43' '60' '32' '37' '49' '39' '50'
#  '44' '30' 'fifty-eight' '29' '31' '54' '57' '27' 'thirty-six' '28' '26'
#  'fifty-five' '25' 'fifty-two' 'thirty-one' '24' 'thirty' '23' '22' '21'
#  '20' 'twenty-six' '19' 'thirty-seven' '18' 'thirty-two' 'twenty-four']
#
# Las frecuncias de los valores unicos de las categorías son: age
# 35              88
# 31              88
# 34              86
# 29              82
# 36              79
# 32              66
# 30              65
# 38              64
# 33              63
# 40              60
# 28              54
# 37              54
# 27              54
# 45              50
# 42              50
# 41              48
# 39              46
# 26              46
# 43              42
# 46              38
# 44              34
# 50              34
# 47              30
# ...

# %%
# Contar valores NULOS por columna
df.isnull().sum()
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# ...

# %%
# Mostrar solo las columnas con los valores nulos y el total de ellos
df.isna().sum()[df.isna().sum() > 0]
# Out:
# businesstravel          801
# department             1366
# educationfield          774
# hourlyrate             1267
# maritalstatus           675
# monthlyincome           489
# over18                  938
# overtime                696
# performancerating       200
# standardhours           351
# totalworkingyears       549
# worklifebalance         114
# yearsincurrentrole     1643
# sameasmonthlyincome     489
# salary                  285
# roledepartament        1366
# numberchildren         1678
# dtype: int64

# %%
# Mostrar los porcentajes nulos y el número de valores nulos de cada columna
columnas = [
    'businesstravel', 
    'department', 
    'educationfield', 
    'hourlyrate', 
    'maritalstatus', 
    'monthlyincome', 
    'over18', 
    'overtime', 
    'performancerating', 
    'standardhours', 
    'totalworkingyears', 
    'worklifebalance', 
    'yearsincurrentrole', 
    'sameasmonthlyincome', 
    'salary', 
    'roledepartament', 
    'numberchildren'
]

# %%
for col in columnas:
    procentajes_nulos = (df[col].isna().sum() / len(df)) * 100
    print(f'La columna {col.upper()} {df[col].isnull().sum()} tiene valores nulos lo que es igual a {procentajes_nulos.round()} %')
# Out:
# La columna BUSINESSTRAVEL 801 tiene valores nulos lo que es igual a 48.0 %
# La columna DEPARTMENT 1366 tiene valores nulos lo que es igual a 81.0 %
# La columna EDUCATIONFIELD 774 tiene valores nulos lo que es igual a 46.0 %
# La columna HOURLYRATE 1267 tiene valores nulos lo que es igual a 76.0 %
# La columna MARITALSTATUS 675 tiene valores nulos lo que es igual a 40.0 %
# La columna MONTHLYINCOME 489 tiene valores nulos lo que es igual a 29.0 %
# La columna OVER18 938 tiene valores nulos lo que es igual a 56.0 %
# La columna OVERTIME 696 tiene valores nulos lo que es igual a 41.0 %
# La columna PERFORMANCERATING 200 tiene valores nulos lo que es igual a 12.0 %
# La columna STANDARDHOURS 351 tiene valores nulos lo que es igual a 21.0 %
# La columna TOTALWORKINGYEARS 549 tiene valores nulos lo que es igual a 33.0 %
# La columna WORKLIFEBALANCE 114 tiene valores nulos lo que es igual a 7.0 %
# La columna YEARSINCURRENTROLE 1643 tiene valores nulos lo que es igual a 98.0 %
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1673     True
# 1674     True
# 1675     True
# 1676     True
# 1677     True
# Length: 1678, dtype: bool

# %%
# Contar valores duplicados en todo el dataset
duplicados = df.duplicated().sum()
print(f"Valores duplicados en el dataset: {duplicados}")
# Out:
# Valores duplicados en el dataset: 64

# %%
# Ver los tipos de las columnas
df.dtypes
# Out:
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# ...
